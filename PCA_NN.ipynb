# %% [markdown]
# <a href="https://colab.research.google.com/github/debanjanchatterjee/tuberculosis-drug-resistance-classification/blob/master/PCA_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing the librares

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import csv

# %% [markdown]
# # Importing the Dataset

# %%
#dataset = pd.read_csv('X_trainData_1.csv')
#labels=pd.read_csv('Y_trainData_1.csv')
dataset = pd.read_csv('X_trainData_column_modified_PCA_KAN.csv')
datalabels=pd.read_csv('X_trainData_column_modified_KAN.csv')


X_train=dataset.iloc[:,:].values
y_train=datalabels.iloc[:,-1].values

# %%
print(X_train)
# Out:
# [[ 1.00000000e+00  1.06457480e+02 -1.96746360e+01 ...  3.66072407e-01
#   -2.66333792e-01 -5.14731742e-01]
#  [ 2.00000000e+00  1.11981931e+02 -2.05409581e+01 ...  9.27882986e-03
#    9.32456546e-01  9.10195125e-01]
#  [ 3.00000000e+00  9.72980251e+01 -2.00279612e+01 ... -6.99730336e-01
#    1.53423863e-01 -2.40960537e-01]
#  ...
#  [ 1.28100000e+03  1.11804246e+02  4.55986775e+01 ...  7.60170775e-01
#   -9.28720257e-02  2.88644192e-01]
#  [ 1.28200000e+03  1.06643859e+02  4.11893891e+01 ... -1.13931373e+00
#    2.09039606e-01 -1.18579060e+00]
#  [ 1.28300000e+03  1.12095208e+02  4.77414702e+01 ...  5.33797829e-01
#    3.16645680e-02  1.17570100e-01]]

# %%
print(y_train)

count1=0
count0=0

for n in y_train:
  if n==1:
    count1=count1+1
  else:
    count0=count0+1

print(count1)
print(count0)
# Out:
# [1 1 0 ... 1 1 1]
# 1013
# 270

# %% [markdown]
# # Building the ANN

# %%
ann = tf.keras.models.Sequential()

#class_weight={1:1, 0:5}

ann.add(tf.keras.layers.Dense(units=128, activation='relu'))

ann.add(tf.keras.layers.Dense(units=64, activation='relu'))

ann.add(tf.keras.layers.Dense(units=32, activation='relu'))

ann.add(tf.keras.layers.Dense(units=12, activation='relu'))

ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

ann.fit(X_train, y_train, batch_size = 16, epochs = 100)
# Out:
# Epoch 1/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5101 - accuracy: 0.7880
# Epoch 2/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4145 - accuracy: 0.7919
# Epoch 3/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3493 - accuracy: 0.8691
# Epoch 4/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2699 - accuracy: 0.9080
# Epoch 5/100
# 81/81 [==============================] - 0s 3ms/step - loss: 0.2316 - accuracy: 0.9228
# Epoch 6/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2355 - accuracy: 0.9135
# Epoch 7/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1875 - accuracy: 0.9275
# Epoch 8/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1876 - accuracy: 0.9291
# Epoch 9/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1886 - accuracy: 0.9330
# Epoch 10/100
# ...

# %%
#from xgboost import XGBClassifier
#classifier = XGBClassifier()
#classifier.fit(X_train, y_train)

#from sklearn.ensemble import RandomForestClassifier
#classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
#classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %% [markdown]
# #Predicting Validation set results

# %%
test_data = pd.read_csv('X_testData_column_modified_PCA_KAN.csv')


X_test=test_data.iloc[:,:].values


print(type(X_test))
print(len(X_test))
print(len(X_test[0]))
print(X_test)
# Out:
# <class 'numpy.ndarray'>
# 498
# 156
# [[ 1.00000000e+00  1.04648724e+02  4.10039682e+01 ...  1.92228428e-01
#    3.05391612e+00 -1.56085046e-01]
#  [ 2.00000000e+00  1.08460088e+02  3.35830749e+01 ... -8.30902390e+00
#   -1.30633116e-01 -1.99299947e-01]
#  [ 3.00000000e+00  1.07520355e+02  4.06022828e+01 ...  5.03919994e-01
#    8.31935218e-01 -5.49290371e-01]
#  ...
#  [ 4.96000000e+02  1.10837942e+02  4.43333636e+01 ...  3.98681420e-02
#   -9.43716559e-01  1.64839185e-01]
#  [ 4.97000000e+02  1.10433116e+02  4.41404393e+01 ... -2.98994840e-01
#    2.41883388e-01  1.46001383e+00]
#  [ 4.98000000e+02  1.10735584e+02  4.46892518e+01 ...  1.83595256e-01
#   -8.74243967e-01 -1.99543813e-01]]

# %%
#y_pred = classifier.predict_proba(X_test)
#y_pred = classifier.predict(X_test)
y_pred = ann.predict(X_test)
print(y_pred)

print(type(y_pred))
#y_pred = (y_pred > 0.5)
#print(np.concatenate((y_pred.reshape(len(y_pred),1), y_validation.reshape(len(y_validation),1)),1))
# Out:
# [[1.00000000e+00]
#  [9.99999881e-01]
#  [1.00000000e+00]
#  [9.99999166e-01]
#  [9.99989748e-01]
#  [1.00000000e+00]
#  [1.00000000e+00]
#  [9.99999881e-01]
#  [9.99999881e-01]
#  [1.00000000e+00]
#  [1.00000000e+00]
#  [9.99845147e-01]
#  [9.99993682e-01]
#  [9.99999881e-01]
#  [9.99993801e-01]
#  [1.00000000e+00]
#  [1.00000000e+00]
#  [9.99999881e-01]
#  [1.00000000e+00]
#  [9.99999523e-01]
#  [1.00000000e+00]
#  [9.99997735e-01]
#  [1.00000000e+00]
#  [9.99998450e-01]
#  [1.00000000e+00]
#  [1.00000000e+00]
#  [1.00000000e+00]
#  [1.00000000e+00]
#  [9.99687672e-01]
#  [1.00000000e+00]
#  [1.00000000e+00]
#  [9.99984503e-01]
#  [9.99922991e-01]
#  [1.00000000e+00]
#  [2.17582254e-07]
#  [9.99958515e-01]
#  [1.00000000e+00]
#  [1.00000000e+00]
#  [9.99951720e-01]
#  [9.99995232e-01]
#  [9.99999881e-01]
#  [9.99999285e-01]
#  [9.99999166e-01]
#  [1.00000000e+00]
#  [9.99999642e-01]
#  [9.99992132e-01]
#  [1.00000000e+00]
#  [9.99988556e-01]
#  [9.99907494e-01]
#  [9.99997735e-01]
# ...

# %%
print(len(y_pred))
# Out:
# 498

# %%
submission_data = pd.read_csv('Y_testData_1_nolabels_KAN.csv')

ids=submission_data.iloc[:,:1].values
result=list()
k=0
#print(ids)
#print(y_pred[0])
for i in ids:
  #result.append([ i[0], y_pred[i[0]-1][0] ])
  result.append([ i[0], y_pred[k][0] ])
  #result.append([ i[0], y_pred[k][1] ])
  k=k+1
  #print(y_pred[i[0]-1][0])
  #print('.')

result.insert(0, ['ID','KAN'])
print(result)
# Out:
# [['ID', 'KAN'], [1, 1.0], [2, 0.9999999], [3, 1.0], [4, 0.99999917], [5, 0.99998975], [6, 1.0], [7, 1.0], [8, 0.9999999], [9, 0.9999999], [10, 1.0], [11, 1.0], [12, 0.99984515], [13, 0.9999937], [14, 0.9999999], [15, 0.9999938], [16, 1.0], [17, 1.0], [18, 0.9999999], [19, 1.0], [20, 0.9999995], [21, 1.0], [22, 0.99999774], [23, 1.0], [24, 0.99999845], [25, 1.0], [26, 1.0], [27, 1.0], [28, 1.0], [29, 0.9996877], [30, 1.0], [31, 1.0], [32, 0.9999845], [33, 0.999923], [34, 1.0], [35, 2.1758225e-07], [36, 0.9999585], [37, 1.0], [38, 1.0], [39, 0.9999517], [40, 0.99999523], [41, 0.9999999], [42, 0.9999993], [43, 0.99999917], [44, 1.0], [45, 0.99999964], [46, 0.99999213], [47, 1.0], [48, 0.99998856], [49, 0.9999075], [50, 0.99999774], [51, 0.99999857], [52, 1.0], [53, 0.99999917], [54, 0.9999603], [55, 1.0], [56, 0.9843038], [57, 0.9999999], [58, 0.9999963], [59, 0.9998522], [60, 1.0], [61, 0.9999944], [62, 1.0], [63, 0.99999905], [64, 0.99999917], [65, 1.0], [66, 1.0], [67, 0.99999464], [
# ...

# %%
file = open('KAN_result.csv', 'w+', newline ='') 
  
# writing the data into the file 
with file:     
    write = csv.writer(file) 
    write.writerows(result)

# %% [markdown]
# # Making the Confusion Matrix
